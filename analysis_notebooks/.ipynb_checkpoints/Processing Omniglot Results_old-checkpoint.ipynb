# %%
import numpy as np
#     0|2|4              model|alphabet|samples
#                           v       v       v
#      1|3                challenge|characters
#                               v       v
total_successes = np.zeros((3,  3,  5,  5,  2))
total_lengths =   np.zeros((3,  3,  5,  5,  2))
total_accuracies =   np.zeros((3,  3,  5,  5,  2))

# %%
import glob
models = ["cnn_1", "cnn_2", "higsfa"]
for id0, model in enumerate(models):
    model_root = "../experimental_data" + "/" + model
    print(sorted(glob.glob(model_root + "/*")))
    for id1, challengeno in enumerate(sorted(glob.glob(model_root + "/*"))):    
        for id2, alphabetno in enumerate(sorted(glob.glob(challengeno + "/*"))):    
            for id3, characterno in enumerate(sorted(glob.glob(alphabetno + "/*"))):
                for id4, sampleno in enumerate(sorted(glob.glob(characterno + "/*"))):
                    print(sampleno)
                    total_success = 0
                    total_length = 0
                    accuracies = []
                    for instance in glob.iglob(sampleno + "/*"):
                        with open(instance) as f:
                            content = f.readlines()
                            success = 0
                            for line in content:
                                split = line.split(",")
                                if split[0] == split[1].strip():
                                    success = success + 1
                            total_success +=  success
                            total_length  += len(content)-1
                            accuracies.append(float(success)/len(content)-1)
                    print("hmm")
                    print(np.std(accuracies) / np.sqrt(len(accuracies)))
                    print(total_success)
                    print("ids %i, %i, %i, %i, %i" % (id0, id1, id2, id3, id4))
                    total_successes[id0, id1, id2, id3, id4] += total_success
                    total_lengths  [id0, id1, id2, id3, id4] += total_length
                    total_accuracies  [id0, id1, id2, id3, id4] += np.std(accuracies) / np.sqrt(len(accuracies))
                    print(total_success / float(total_length))
# Out:
# ['experimental_data/cnn_1/challenge0', 'experimental_data/cnn_1/challenge1', 'experimental_data/cnn_1/challenge2']
# experimental_data/cnn_1/challenge0/10_alphabets/8_characters/16_samples
# hmm
# 0.00960021158621
# 4972
# ids 0, 0, 0, 0, 0
# 0.391496062992
# experimental_data/cnn_1/challenge0/10_alphabets/8_characters/4_samples
# hmm
# 0.0091235015893
# 1442
# ids 0, 0, 0, 0, 1
# 0.465161290323
# experimental_data/cnn_1/challenge0/12_alphabets/8_characters/16_samples
# hmm
# 0.00982816226146
# 4668
# ids 0, 0, 1, 0, 0
# 0.367559055118
# experimental_data/cnn_1/challenge0/12_alphabets/8_characters/4_samples
# hmm
# 0.00986253168563
# 1486
# ids 0, 0, 1, 0, 1
# 0.47935483871
# experimental_data/cnn_1/challenge0/4_alphabets/8_characters/16_samples
# hmm
# 0.00847727891558
# 6176
# ids 0, 0, 2, 0, 0
# 0.486299212598
# experimental_data/cnn_1/challenge0/4_alphabets/8_characters/4_samples
# hmm
# 0.0102899374391
# 1576
# ids 0, 0, 2, 0, 1
# 0.508387096774
# experimental_data/cnn_1/challenge0/6_alphabets/8_characters/16_samples
# hmm
# 0.00779881614113
# 5890
# ids 0, 0, 3, 0, 0
# 0.463779527559
# experimental_data/cnn_1/challenge0/6_alphabets/8_characters/4_samples
# hmm
# 0.00944784201551
# 1514
# ids 0, 0, 3, 0, 1
# 0.488387096774
# experimental_data/cnn_1/challenge0/8_alphabets/10_characters/16_samples
# hmm
# 0.00911982141153
# 4882
# ids 0, 0, 4, 0, 0
# 0.384409448819
# experimental_data/cnn_1/challenge0/8_alphabets/10_characters/4_samples
# hmm
# 0.0094873991266
# 1477
# ids 0, 0, 4, 0, 1
# 0.476451612903
# experimental_data/cnn_1/challenge0/8_alphabets/12_characters/16_samples
# hmm
# 0.00984963551733
# 4549
# ids 0, 0, 4, 1, 0
# 0.358188976378
# experimental_data/cnn_1/challenge0/8_alphabets/12_characters/4_samples
# hmm
# 0.010708267469
# 1459
# ids 0, 0, 4, 1, 1
# 0.47064516129
# experimental_data/cnn_1/challenge0/8_alphabets/4_characters/16_samples
# hmm
# 0.00733050667587
# 6472
# ids 0, 0, 4, 2, 0
# 0.509606299213
# experimental_data/cnn_1/challenge0/8_alphabets/4_characters/4_samples
# hmm
# 0.00952356247354
# 1605
# ids 0, 0, 4, 2, 1
# 0.517741935484
# experimental_data/cnn_1/challenge0/8_alphabets/6_characters/16_samples
# hmm
# 0.00767956828493
# 5979
# ids 0, 0, 4, 3, 0
# 0.470787401575
# experimental_data/cnn_1/challenge0/8_alphabets/6_characters/4_samples
# hmm
# 0.00933716323021
# 1485
# ids 0, 0, 4, 3, 1
# 0.479032258065
# experimental_data/cnn_1/challenge0/8_alphabets/8_characters/16_samples
# hmm
# 0.00742183799333
# 5553
# ids 0, 0, 4, 4, 0
# 0.437244094488
# experimental_data/cnn_1/challenge0/8_alphabets/8_characters/4_samples
# hmm
# 0.00924936653236
# 1514
# ids 0, 0, 4, 4, 1
# 0.488387096774
# experimental_data/cnn_1/challenge1/10_alphabets/8_characters/16_samples
# hmm
# 0.0115096342117
# 1207
# ids 0, 1, 0, 0, 0
# 0.38935483871
# experimental_data/cnn_1/challenge1/10_alphabets/8_characters/4_samples
# hmm
# 0.00630735402873
# 5500
# ids 0, 1, 0, 0, 1
# 0.433070866142
# experimental_data/cnn_1/challenge1/12_alphabets/8_characters/16_samples
# hmm
# 0.0124471931449
# 1143
# ids 0, 1, 1, 0, 0
# 0.368709677419
# experimental_data/cnn_1/challenge1/12_alphabets/8_characters/4_samples
# hmm
# 0.00527964911942
# 5501
# ids 0, 1, 1, 0, 1
# 0.433149606299
# experimental_data/cnn_1/challenge1/4_alphabets/8_characters/16_samples
# hmm
# 0.0089819154242
# 1467
# ids 0, 1, 2, 0, 0
# 0.473225806452
# experimental_data/cnn_1/challenge1/4_alphabets/8_characters/4_samples
# hmm
# 0.00642684855308
# 5113
# ids 0, 1, 2, 0, 1
# 0.402598425197
# experimental_data/cnn_1/challenge1/6_alphabets/8_characters/16_samples
# hmm
# 0.0105994177316
# 1466
# ids 0, 1, 3, 0, 0
# 0.472903225806
# experimental_data/cnn_1/challenge1/6_alphabets/8_characters/4_samples
# hmm
# 0.00575230825782
# 5537
# ids 0, 1, 3, 0, 1
# 0.435984251969
# experimental_data/cnn_1/challenge1/8_alphabets/10_characters/16_samples
# hmm
# 0.0114710913823
# 1216
# ids 0, 1, 4, 0, 0
# 0.392258064516
# experimental_data/cnn_1/challenge1/8_alphabets/10_characters/4_samples
# hmm
# 0.00558061372178
# 5507
# ids 0, 1, 4, 0, 1
# 0.433622047244
# experimental_data/cnn_1/challenge1/8_alphabets/12_characters/16_samples
# hmm
# 0.0115867566509
# 1115
# ids 0, 1, 4, 1, 0
# 0.359677419355
# experimental_data/cnn_1/challenge1/8_alphabets/12_characters/4_samples
# hmm
# 0.0057445785838
# 5325
# ids 0, 1, 4, 1, 1
# 0.419291338583
# experimental_data/cnn_1/challenge1/8_alphabets/4_characters/16_samples
# hmm
# 0.00992525778947
# 1565
# ids 0, 1, 4, 2, 0
# 0.504838709677
# experimental_data/cnn_1/challenge1/8_alphabets/4_characters/4_samples
# hmm
# 0.00614201141315
# 5525
# ids 0, 1, 4, 2, 1
# 0.435039370079
# experimental_data/cnn_1/challenge1/8_alphabets/6_characters/16_samples
# hmm
# 0.0108965304111
# 1404
# ids 0, 1, 4, 3, 0
# 0.452903225806
# experimental_data/cnn_1/challenge1/8_alphabets/6_characters/4_samples
# hmm
# 0.00589946700453
# 5576
# ids 0, 1, 4, 3, 1
# 0.43905511811
# experimental_data/cnn_1/challenge1/8_alphabets/8_characters/16_samples
# hmm
# 0.010398129339
# 1378
# ids 0, 1, 4, 4, 0
# 0.444516129032
# experimental_data/cnn_1/challenge1/8_alphabets/8_characters/4_samples
# hmm
# 0.00700883580182
# 5666
# ids 0, 1, 4, 4, 1
# 0.446141732283
# experimental_data/cnn_1/challenge2/10_alphabets/8_characters/16_samples
# hmm
# 0.00886011956748
# 2717
# ids 0, 2, 0, 0, 0
# 0.343924050633
# experimental_data/cnn_1/challenge2/10_alphabets/8_characters/4_samples
# hmm
# 0.00786840994102
# 3058
# ids 0, 2, 0, 0, 1
# 0.387088607595
# experimental_data/cnn_1/challenge2/12_alphabets/8_characters/16_samples
# hmm
# 0.0100489116326
# 2482
# ids 0, 2, 1, 0, 0
# 0.31417721519
# experimental_data/cnn_1/challenge2/12_alphabets/8_characters/4_samples
# hmm
# 0.00680784244456
# 3009
# ids 0, 2, 1, 0, 1
# 0.380886075949
# experimental_data/cnn_1/challenge2/4_alphabets/8_characters/16_samples
# hmm
# 0.00805159145759
# 2990
# ids 0, 2, 2, 0, 0
# 0.378481012658
# experimental_data/cnn_1/challenge2/4_alphabets/8_characters/4_samples
# hmm
# 0.007813249964
# 2810
# ids 0, 2, 2, 0, 1
# 0.355696202532
# experimental_data/cnn_1/challenge2/6_alphabets/8_characters/16_samples
# hmm
# 0.00813207384374
# 3042
# ids 0, 2, 3, 0, 0
# 0.385063291139
# experimental_data/cnn_1/challenge2/6_alphabets/8_characters/4_samples
# hmm
# 0.00858977408027
# 2959
# ids 0, 2, 3, 0, 1
# 0.374556962025
# experimental_data/cnn_1/challenge2/8_alphabets/10_characters/16_samples
# hmm
# 0.0083581920892
# 2690
# ids 0, 2, 4, 0, 0
# 0.340506329114
# experimental_data/cnn_1/challenge2/8_alphabets/10_characters/4_samples
# hmm
# 0.00796094961358
# 3017
# ids 0, 2, 4, 0, 1
# 0.381898734177
# experimental_data/cnn_1/challenge2/8_alphabets/12_characters/16_samples
# hmm
# 0.00999062060134
# 2500
# ids 0, 2, 4, 1, 0
# 0.316455696203
# experimental_data/cnn_1/challenge2/8_alphabets/12_characters/4_samples
# hmm
# 0.00754754720091
# 2939
# ids 0, 2, 4, 1, 1
# 0.372025316456
# experimental_data/cnn_1/challenge2/8_alphabets/4_characters/16_samples
# hmm
# 0.00713267130884
# 3180
# ids 0, 2, 4, 2, 0
# 0.40253164557
# experimental_data/cnn_1/challenge2/8_alphabets/4_characters/4_samples
# hmm
# 0.00754983443527
# 3040
# ids 0, 2, 4, 2, 1
# 0.384810126582
# experimental_data/cnn_1/challenge2/8_alphabets/6_characters/16_samples
# hmm
# 0.0075811855933
# 3042
# ids 0, 2, 4, 3, 0
# 0.385063291139
# experimental_data/cnn_1/challenge2/8_alphabets/6_characters/4_samples
# hmm
# 0.00666830188279
# 3004
# ids 0, 2, 4, 3, 1
# 0.380253164557
# experimental_data/cnn_1/challenge2/8_alphabets/8_characters/16_samples
# hmm
# 0.00708237248385
# 3024
# ids 0, 2, 4, 4, 0
# 0.382784810127
# experimental_data/cnn_1/challenge2/8_alphabets/8_characters/4_samples
# hmm
# 0.00765844101303
# 3127
# ids 0, 2, 4, 4, 1
# 0.39582278481
# ['experimental_data/cnn_2/challenge0', 'experimental_data/cnn_2/challenge1', 'experimental_data/cnn_2/challenge2']
# experimental_data/cnn_2/challenge0/10_alphabets/8_characters/16_samples
# hmm
# 0.00642422687317
# 6039
# ids 1, 0, 0, 0, 0
# 0.475511811024
# experimental_data/cnn_2/challenge0/10_alphabets/8_characters/4_samples
# hmm
# 0.00839712562428
# 1386
# ids 1, 0, 0, 0, 1
# 0.447096774194
# experimental_data/cnn_2/challenge0/12_alphabets/8_characters/16_samples
# hmm
# 0.00644691741382
# 6106
# ids 1, 0, 1, 0, 0
# 0.480787401575
# experimental_data/cnn_2/challenge0/12_alphabets/8_characters/4_samples
# hmm
# 0.00953708837578
# 1369
# ids 1, 0, 1, 0, 1
# 0.441612903226
# experimental_data/cnn_2/challenge0/4_alphabets/8_characters/16_samples
# hmm
# 0.0071923005368
# 5837
# ids 1, 0, 2, 0, 0
# 0.459606299213
# experimental_data/cnn_2/challenge0/4_alphabets/8_characters/4_samples
# hmm
# 0.00900325461986
# 1314
# ids 1, 0, 2, 0, 1
# 0.423870967742
# experimental_data/cnn_2/challenge0/6_alphabets/8_characters/16_samples
# hmm
# 0.00695301966212
# 6018
# ids 1, 0, 3, 0, 0
# 0.473858267717
# experimental_data/cnn_2/challenge0/6_alphabets/8_characters/4_samples
# hmm
# 0.0100372353639
# 1406
# ids 1, 0, 3, 0, 1
# 0.453548387097
# experimental_data/cnn_2/challenge0/8_alphabets/10_characters/16_samples
# hmm
# 0.00725669814508
# 5968
# ids 1, 0, 4, 0, 0
# 0.469921259843
# experimental_data/cnn_2/challenge0/8_alphabets/10_characters/4_samples
# hmm
# 0.00884899358684
# 1396
# ids 1, 0, 4, 0, 1
# 0.450322580645
# experimental_data/cnn_2/challenge0/8_alphabets/12_characters/16_samples
# hmm
# 0.00638152144226
# 5809
# ids 1, 0, 4, 1, 0
# 0.457401574803
# experimental_data/cnn_2/challenge0/8_alphabets/12_characters/4_samples
# hmm
# 0.00897974065257
# 1323
# ids 1, 0, 4, 1, 1
# 0.426774193548
# experimental_data/cnn_2/challenge0/8_alphabets/4_characters/16_samples
# hmm
# 0.00622634194246
# 6094
# ids 1, 0, 4, 2, 0
# 0.479842519685
# experimental_data/cnn_2/challenge0/8_alphabets/4_characters/4_samples
# hmm
# 0.00970557789045
# 1371
# ids 1, 0, 4, 2, 1
# 0.442258064516
# experimental_data/cnn_2/challenge0/8_alphabets/6_characters/16_samples
# hmm
# 0.00684697769206
# 6190
# ids 1, 0, 4, 3, 0
# 0.487401574803
# experimental_data/cnn_2/challenge0/8_alphabets/6_characters/4_samples
# hmm
# 0.0100067848077
# 1369
# ids 1, 0, 4, 3, 1
# 0.441612903226
# experimental_data/cnn_2/challenge0/8_alphabets/8_characters/16_samples
# hmm
# 0.00632414516055
# 6075
# ids 1, 0, 4, 4, 0
# 0.478346456693
# experimental_data/cnn_2/challenge0/8_alphabets/8_characters/4_samples
# hmm
# 0.00849724219968
# 1392
# ids 1, 0, 4, 4, 1
# 0.449032258065
# experimental_data/cnn_2/challenge1/10_alphabets/8_characters/16_samples
# hmm
# 0.00983377470761
# 1476
# ids 1, 1, 0, 0, 0
# 0.476129032258
# experimental_data/cnn_2/challenge1/10_alphabets/8_characters/4_samples
# hmm
# 0.00565920589201
# 5374
# ids 1, 1, 0, 0, 1
# 0.423149606299
# experimental_data/cnn_2/challenge1/12_alphabets/8_characters/16_samples
# hmm
# 0.00944267242363
# 1464
# ids 1, 1, 1, 0, 0
# 0.472258064516
# experimental_data/cnn_2/challenge1/12_alphabets/8_characters/4_samples
# hmm
# 0.00483175808898
# 5301
# ids 1, 1, 1, 0, 1
# 0.417401574803
# experimental_data/cnn_2/challenge1/4_alphabets/8_characters/16_samples
# hmm
# 0.00912473244471
# 1429
# ids 1, 1, 2, 0, 0
# 0.460967741935
# experimental_data/cnn_2/challenge1/4_alphabets/8_characters/4_samples
# hmm
# 0.00591424310325
# 5046
# ids 1, 1, 2, 0, 1
# 0.397322834646
# experimental_data/cnn_2/challenge1/6_alphabets/8_characters/16_samples
# hmm
# 0.0100663812391
# 1506
# ids 1, 1, 3, 0, 0
# 0.485806451613
# experimental_data/cnn_2/challenge1/6_alphabets/8_characters/4_samples
# hmm
# 0.00545576024255
# 5395
# ids 1, 1, 3, 0, 1
# 0.424803149606
# experimental_data/cnn_2/challenge1/8_alphabets/10_characters/16_samples
# hmm
# 0.00984503959807
# 1493
# ids 1, 1, 4, 0, 0
# 0.481612903226
# experimental_data/cnn_2/challenge1/8_alphabets/10_characters/4_samples
# hmm
# 0.00561237189268
# 5345
# ids 1, 1, 4, 0, 1
# 0.420866141732
# experimental_data/cnn_2/challenge1/8_alphabets/12_characters/16_samples
# hmm
# 0.00981767379525
# 1470
# ids 1, 1, 4, 1, 0
# 0.474193548387
# experimental_data/cnn_2/challenge1/8_alphabets/12_characters/4_samples
# hmm
# 0.00512820855165
# 5145
# ids 1, 1, 4, 1, 1
# 0.405118110236
# experimental_data/cnn_2/challenge1/8_alphabets/4_characters/16_samples
# hmm
# 0.0100911374328
# 1485
# ids 1, 1, 4, 2, 0
# 0.479032258065
# experimental_data/cnn_2/challenge1/8_alphabets/4_characters/4_samples
# hmm
# 0.0069208829354
# 5323
# ids 1, 1, 4, 2, 1
# 0.419133858268
# experimental_data/cnn_2/challenge1/8_alphabets/6_characters/16_samples
# hmm
# 0.0107264913736
# 1541
# ids 1, 1, 4, 3, 0
# 0.497096774194
# experimental_data/cnn_2/challenge1/8_alphabets/6_characters/4_samples
# hmm
# 0.00708700119497
# 5452
# ids 1, 1, 4, 3, 1
# 0.429291338583
# experimental_data/cnn_2/challenge1/8_alphabets/8_characters/16_samples
# hmm
# 0.0110156139184
# 1488
# ids 1, 1, 4, 4, 0
# 0.48
# experimental_data/cnn_2/challenge1/8_alphabets/8_characters/4_samples
# hmm
# 0.00625398310579
# 5372
# ids 1, 1, 4, 4, 1
# 0.422992125984
# experimental_data/cnn_2/challenge2/10_alphabets/8_characters/16_samples
# hmm
# 0.00746930175786
# 3421
# ids 1, 2, 0, 0, 0
# 0.433037974684
# experimental_data/cnn_2/challenge2/10_alphabets/8_characters/4_samples
# hmm
# 0.00796770826524
# 3070
# ids 1, 2, 0, 0, 1
# 0.388607594937
# experimental_data/cnn_2/challenge2/12_alphabets/8_characters/16_samples
# hmm
# 0.0082560205305
# 3342
# ids 1, 2, 1, 0, 0
# 0.423037974684
# experimental_data/cnn_2/challenge2/12_alphabets/8_characters/4_samples
# hmm
# 0.00729275110984
# 3111
# ids 1, 2, 1, 0, 1
# 0.393797468354
# experimental_data/cnn_2/challenge2/4_alphabets/8_characters/16_samples
# hmm
# 0.00883928553391
# 3243
# ids 1, 2, 2, 0, 0
# 0.410506329114
# experimental_data/cnn_2/challenge2/4_alphabets/8_characters/4_samples
# hmm
# 0.00814904135466
# 2886
# ids 1, 2, 2, 0, 1
# 0.365316455696
# experimental_data/cnn_2/challenge2/6_alphabets/8_characters/16_samples
# hmm
# 0.00833854004008
# 3360
# ids 1, 2, 3, 0, 0
# 0.425316455696
# experimental_data/cnn_2/challenge2/6_alphabets/8_characters/4_samples
# hmm
# 0.00751872662091
# 3000
# ids 1, 2, 3, 0, 1
# 0.379746835443
# experimental_data/cnn_2/challenge2/8_alphabets/10_characters/16_samples
# hmm
# 0.00679700071723
# 3365
# ids 1, 2, 4, 0, 0
# 0.425949367089
# experimental_data/cnn_2/challenge2/8_alphabets/10_characters/4_samples
# hmm
# 0.00734263023378
# 3043
# ids 1, 2, 4, 0, 1
# 0.385189873418
# experimental_data/cnn_2/challenge2/8_alphabets/12_characters/16_samples
# hmm
# 0.00761629626196
# 3293
# ids 1, 2, 4, 1, 0
# 0.416835443038
# experimental_data/cnn_2/challenge2/8_alphabets/12_characters/4_samples
# hmm
# 0.00741636703515
# 3072
# ids 1, 2, 4, 1, 1
# 0.388860759494
# experimental_data/cnn_2/challenge2/8_alphabets/4_characters/16_samples
# hmm
# 0.00732899848206
# 3323
# ids 1, 2, 4, 2, 0
# 0.420632911392
# experimental_data/cnn_2/challenge2/8_alphabets/4_characters/4_samples
# hmm
# 0.00674549618264
# 3017
# ids 1, 2, 4, 2, 1
# 0.381898734177
# experimental_data/cnn_2/challenge2/8_alphabets/6_characters/16_samples
# hmm
# 0.00806806978155
# 3400
# ids 1, 2, 4, 3, 0
# 0.430379746835
# experimental_data/cnn_2/challenge2/8_alphabets/6_characters/4_samples
# hmm
# 0.00673696658371
# 2955
# ids 1, 2, 4, 3, 1
# 0.374050632911
# experimental_data/cnn_2/challenge2/8_alphabets/8_characters/16_samples
# hmm
# 0.00762803218399
# 3398
# ids 1, 2, 4, 4, 0
# 0.430126582278
# experimental_data/cnn_2/challenge2/8_alphabets/8_characters/4_samples
# hmm
# 0.00755474809309
# 3125
# ids 1, 2, 4, 4, 1
# 0.395569620253
# ['experimental_data/higsfa/challenge0', 'experimental_data/higsfa/challenge1', 'experimental_data/higsfa/challenge2']
# experimental_data/higsfa/challenge0/10_alphabets/8_characters/16_samples
# hmm
# 0.00545544698952
# 5491
# ids 2, 0, 0, 0, 0
# 0.432362204724
# experimental_data/higsfa/challenge0/10_alphabets/8_characters/4_samples
# hmm
# 0.00767624938935
# 1319
# ids 2, 0, 0, 0, 1
# 0.425483870968
# experimental_data/higsfa/challenge0/12_alphabets/8_characters/16_samples
# hmm
# 0.00556102398781
# 5335
# ids 2, 0, 1, 0, 0
# 0.420078740157
# experimental_data/higsfa/challenge0/12_alphabets/8_characters/4_samples
# hmm
# 0.00914595197341
# 1312
# ids 2, 0, 1, 0, 1
# 0.423225806452
# experimental_data/higsfa/challenge0/4_alphabets/8_characters/16_samples
# hmm
# 0.00637309924942
# 4871
# ids 2, 0, 2, 0, 0
# 0.383543307087
# experimental_data/higsfa/challenge0/4_alphabets/8_characters/4_samples
# hmm
# 0.00871219511662
# 1226
# ids 2, 0, 2, 0, 1
# 0.395483870968
# experimental_data/higsfa/challenge0/6_alphabets/8_characters/16_samples
# hmm
# 0.00584381266678
# 5178
# ids 2, 0, 3, 0, 0
# 0.407716535433
# experimental_data/higsfa/challenge0/6_alphabets/8_characters/4_samples
# hmm
# 0.00853960213871
# 1255
# ids 2, 0, 3, 0, 1
# 0.404838709677
# experimental_data/higsfa/challenge0/8_alphabets/10_characters/16_samples
# hmm
# 0.00531554944648
# 5237
# ids 2, 0, 4, 0, 0
# 0.412362204724
# experimental_data/higsfa/challenge0/8_alphabets/10_characters/4_samples
# hmm
# 0.0094375
# 1314
# ids 2, 0, 4, 0, 1
# 0.423870967742
# experimental_data/higsfa/challenge0/8_alphabets/12_characters/16_samples
# hmm
# 0.00500692879293
# 5292
# ids 2, 0, 4, 1, 0
# 0.416692913386
# experimental_data/higsfa/challenge0/8_alphabets/12_characters/4_samples
# hmm
# 0.00919175071736
# 1278
# ids 2, 0, 4, 1, 1
# 0.412258064516
# experimental_data/higsfa/challenge0/8_alphabets/4_characters/16_samples
# hmm
# 0.00661454437324
# 5242
# ids 2, 0, 4, 2, 0
# 0.412755905512
# experimental_data/higsfa/challenge0/8_alphabets/4_characters/4_samples
# hmm
# 0.0106900124971
# 1291
# ids 2, 0, 4, 2, 1
# 0.416451612903
# experimental_data/higsfa/challenge0/8_alphabets/6_characters/16_samples
# hmm
# 0.00549397641563
# 5363
# ids 2, 0, 4, 3, 0
# 0.422283464567
# experimental_data/higsfa/challenge0/8_alphabets/6_characters/4_samples
# hmm
# 0.00871258742783
# 1263
# ids 2, 0, 4, 3, 1
# 0.407419354839
# experimental_data/higsfa/challenge0/8_alphabets/8_characters/16_samples
# hmm
# 0.00572648789174
# 5245
# ids 2, 0, 4, 4, 0
# 0.412992125984
# experimental_data/higsfa/challenge0/8_alphabets/8_characters/4_samples
# hmm
# 0.0084375
# 1290
# ids 2, 0, 4, 4, 1
# 0.416129032258
# experimental_data/higsfa/challenge1/10_alphabets/8_characters/16_samples
# hmm
# 0.00896041642447
# 1328
# ids 2, 1, 0, 0, 0
# 0.428387096774
# experimental_data/higsfa/challenge1/10_alphabets/8_characters/4_samples
# hmm
# 0.0047440340824
# 4908
# ids 2, 1, 0, 0, 1
# 0.386456692913
# experimental_data/higsfa/challenge1/12_alphabets/8_characters/16_samples
# hmm
# 0.00810881802037
# 1337
# ids 2, 1, 1, 0, 0
# 0.431290322581
# experimental_data/higsfa/challenge1/12_alphabets/8_characters/4_samples
# hmm
# 0.00521169878247
# 4941
# ids 2, 1, 1, 0, 1
# 0.38905511811
# experimental_data/higsfa/challenge1/4_alphabets/8_characters/16_samples
# hmm
# 0.00912644466304
# 1197
# ids 2, 1, 2, 0, 0
# 0.386129032258
# experimental_data/higsfa/challenge1/4_alphabets/8_characters/4_samples
# hmm
# 0.00586197858822
# 4180
# ids 2, 1, 2, 0, 1
# 0.329133858268
# experimental_data/higsfa/challenge1/6_alphabets/8_characters/16_samples
# hmm
# 0.0100861039152
# 1277
# ids 2, 1, 3, 0, 0
# 0.411935483871
# experimental_data/higsfa/challenge1/6_alphabets/8_characters/4_samples
# hmm
# 0.00483148649162
# 4488
# ids 2, 1, 3, 0, 1
# 0.353385826772
# experimental_data/higsfa/challenge1/8_alphabets/10_characters/16_samples
# hmm
# 0.00947215285389
# 1305
# ids 2, 1, 4, 0, 0
# 0.420967741935
# experimental_data/higsfa/challenge1/8_alphabets/10_characters/4_samples
# hmm
# 0.00560218899042
# 4886
# ids 2, 1, 4, 0, 1
# 0.384724409449
# experimental_data/higsfa/challenge1/8_alphabets/12_characters/16_samples
# hmm
# 0.00972954585271
# 1308
# ids 2, 1, 4, 1, 0
# 0.421935483871
# experimental_data/higsfa/challenge1/8_alphabets/12_characters/4_samples
# hmm
# 0.00523131907063
# 4868
# ids 2, 1, 4, 1, 1
# 0.383307086614
# experimental_data/higsfa/challenge1/8_alphabets/4_characters/16_samples
# hmm
# 0.009953946689
# 1279
# ids 2, 1, 4, 2, 0
# 0.412580645161
# experimental_data/higsfa/challenge1/8_alphabets/4_characters/4_samples
# hmm
# 0.00568184707912
# 4313
# ids 2, 1, 4, 2, 1
# 0.339606299213
# experimental_data/higsfa/challenge1/8_alphabets/6_characters/16_samples
# hmm
# 0.00922610935064
# 1306
# ids 2, 1, 4, 3, 0
# 0.421290322581
# experimental_data/higsfa/challenge1/8_alphabets/6_characters/4_samples
# hmm
# 0.00544447177871
# 4621
# ids 2, 1, 4, 3, 1
# 0.363858267717
# experimental_data/higsfa/challenge1/8_alphabets/8_characters/16_samples
# hmm
# 0.00882883017095
# 1309
# ids 2, 1, 4, 4, 0
# 0.422258064516
# experimental_data/higsfa/challenge1/8_alphabets/8_characters/4_samples
# hmm
# 0.00519196908396
# 4688
# ids 2, 1, 4, 4, 1
# 0.369133858268
# experimental_data/higsfa/challenge2/10_alphabets/8_characters/16_samples
# hmm
# 0.00753818404856
# 3055
# ids 2, 2, 0, 0, 0
# 0.386708860759
# experimental_data/higsfa/challenge2/10_alphabets/8_characters/4_samples
# hmm
# 0.00681765859735
# 2795
# ids 2, 2, 0, 0, 1
# 0.353797468354
# experimental_data/higsfa/challenge2/12_alphabets/8_characters/16_samples
# hmm
# 0.00656191664074
# 3168
# ids 2, 2, 1, 0, 0
# 0.401012658228
# experimental_data/higsfa/challenge2/12_alphabets/8_characters/4_samples
# hmm
# 0.00591919546898
# 2842
# ids 2, 2, 1, 0, 1
# 0.359746835443
# experimental_data/higsfa/challenge2/4_alphabets/8_characters/16_samples
# hmm
# 0.00728864699378
# 2798
# ids 2, 2, 2, 0, 0
# 0.35417721519
# experimental_data/higsfa/challenge2/4_alphabets/8_characters/4_samples
# hmm
# 0.00582520117678
# 2327
# ids 2, 2, 2, 0, 1
# 0.294556962025
# experimental_data/higsfa/challenge2/6_alphabets/8_characters/16_samples
# hmm
# 0.007005087437
# 2888
# ids 2, 2, 3, 0, 0
# 0.365569620253
# experimental_data/higsfa/challenge2/6_alphabets/8_characters/4_samples
# hmm
# 0.00688971153242
# 2502
# ids 2, 2, 3, 0, 1
# 0.316708860759
# experimental_data/higsfa/challenge2/8_alphabets/10_characters/16_samples
# hmm
# 0.00768171530324
# 3088
# ids 2, 2, 4, 0, 0
# 0.390886075949
# experimental_data/higsfa/challenge2/8_alphabets/10_characters/4_samples
# hmm
# 0.0070079865154
# 2722
# ids 2, 2, 4, 0, 1
# 0.344556962025
# experimental_data/higsfa/challenge2/8_alphabets/12_characters/16_samples
# hmm
# 0.00732003884894
# 3137
# ids 2, 2, 4, 1, 0
# 0.397088607595
# experimental_data/higsfa/challenge2/8_alphabets/12_characters/4_samples
# hmm
# 0.00687926004378
# 2795
# ids 2, 2, 4, 1, 1
# 0.353797468354
# experimental_data/higsfa/challenge2/8_alphabets/4_characters/16_samples
# hmm
# 0.00642524318606
# 2928
# ids 2, 2, 4, 2, 0
# 0.370632911392
# experimental_data/higsfa/challenge2/8_alphabets/4_characters/4_samples
# hmm
# 0.00671140586986
# 2495
# ids 2, 2, 4, 2, 1
# 0.31582278481
# experimental_data/higsfa/challenge2/8_alphabets/6_characters/16_samples
# hmm
# 0.00664382937394
# 2951
# ids 2, 2, 4, 3, 0
# 0.373544303797
# experimental_data/higsfa/challenge2/8_alphabets/6_characters/4_samples
# hmm
# 0.00685679407595
# 2670
# ids 2, 2, 4, 3, 1
# 0.337974683544
# experimental_data/higsfa/challenge2/8_alphabets/8_characters/16_samples
# hmm
# 0.00692364607703
# 3002
# ids 2, 2, 4, 4, 0
# 0.38
# experimental_data/higsfa/challenge2/8_alphabets/8_characters/4_samples
# hmm
# 0.00606454862294
# 2696
# ids 2, 2, 4, 4, 1
# 0.341265822785

# %%
np.save('total_successes', total_successes)
np.save('total_lengths', total_lengths)
np.save('total_accuracies', total_accuracies)

# %%
["10", "12", "4", "6", "8"]
for j in range(3):
    print("model: " + models[j])
    for i in range(3):
        print("challenge " + str(i))
        divided_matrix = np.divide(total_successes[j, i, :, 0, 1], total_lengths[j, i, :, 0, 1])
        to_num = np.nan_to_num(divided_matrix)
        #print(to_num[j, i, :, 4, 1])
        print(to_num)
        #print(to_num[4, :])
        print(to_num.shape)
        print(np.sum(to_num) / 9.0)
        print("\n")
# Out:
# model: cnn_1
# challenge 0
# [ 0.46516129  0.47935484  0.5083871   0.4883871   0.47645161]
# (5,)
# 0.268637992832
#
#
# challenge 1
# [ 0.43307087  0.43314961  0.40259843  0.43598425  0.43362205]
# (5,)
# 0.23760279965
#
#
# challenge 2
# [ 0.38708861  0.38088608  0.3556962   0.37455696  0.38189873]
# (5,)
# 0.208902953586
#
#
# model: cnn_2
# challenge 0
# [ 0.44709677  0.4416129   0.42387097  0.45354839  0.45032258]
# (5,)
# 0.246272401434
#
#
# challenge 1
# [ 0.42314961  0.41740157  0.39732283  0.42480315  0.42086614]
# (5,)
# 0.231504811899
#
#
# challenge 2
# [ 0.38860759  0.39379747  0.36531646  0.37974684  0.38518987]
# (5,)
# 0.212517580872
#
#
# model: higsfa
# challenge 0
# [ 0.42548387  0.42322581  0.39548387  0.40483871  0.42387097]
# (5,)
# 0.230322580645
#
#
# challenge 1
# [ 0.38645669  0.38905512  0.32913386  0.35338583  0.38472441]
# (5,)
# 0.204750656168
#
#
# challenge 2
# [ 0.35379747  0.35974684  0.29455696  0.31670886  0.34455696]
# (5,)
# 0.185485232068
